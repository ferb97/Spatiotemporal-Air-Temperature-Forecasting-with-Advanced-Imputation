# %% [markdown]
# # Fill Missing Values using MICE Imputation

# %%
import os
import pandas as pd
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer

# Define input and output folders
input_folder = "Input_Folder_for_GNN"
output_folder = "Input_Folder_without_Nan_MICE"

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Initialize the IterativeImputer
imputer = IterativeImputer(max_iter=20, random_state=42)

# Loop through each file in the input folder
for file_name in os.listdir(input_folder):
    if file_name.endswith(".csv"):
        file_path = os.path.join(input_folder, file_name)
        
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Convert 'From Date' to datetime format if not already
        df['From Date'] = pd.to_datetime(df['From Date'])
        
        # Separate the 'From Date' column and the air quality parameters
        from_date = df['From Date']
        data = df.drop(columns=['From Date'])
        
        # Apply MICE (Iterative Imputer)
        imputed_data = imputer.fit_transform(data)
        
        # Convert the imputed data back to a DataFrame
        imputed_df = pd.DataFrame(imputed_data, columns=data.columns)
        
        # Add back the 'From Date' column
        imputed_df.insert(0, 'From Date', from_date)

        # Show number of null values in the imputed DataFrame
        print(f"Number of null values in {file_name} after MICE imputation:")
        print(imputed_df.isnull().sum())
        
        # Save the imputed file to the output folder
        output_path = os.path.join(output_folder, file_name)
        imputed_df.to_csv(output_path, index=False)

print("MICE imputation completed. Files saved to 'Input_Folder_without_Nan_MICE'.")
# Out:
# Number of null values in UP002.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP003.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP004.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Number of null values in UP008.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP009.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP012.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Number of null values in UP014.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Number of null values in UP016.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP017.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Number of null values in UP018.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP019.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP020.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP021.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Number of null values in UP022.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# C:\Users\Asus\AppData\Roaming\Python\Python311\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Number of null values in UP023.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP024.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP025.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP026.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP028.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP029.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP030.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP031.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP032.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP033.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP034.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP035.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP036.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP037.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP038.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP039.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP040.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP041.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP042.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP043.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP044.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP046.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP048.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP049.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP050.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP051.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# Number of null values in UP052.csv after MICE imputation:
# From Date        0
# PM2.5 (ug/m3)    0
# PM10 (ug/m3)     0
# NO (ug/m3)       0
# NO2 (ug/m3)      0
# SO2 (ug/m3)      0
# CO (mg/m3)       0
# Ozone (ug/m3)    0
# RH (%)           0
# WS (m/s)         0
# WD (degree)      0
# AT (degree C)    0
# dtype: int64
# MICE imputation completed. Files saved to 'Input_Folder_without_Nan_MICE'.
